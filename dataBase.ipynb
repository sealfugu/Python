# %%
import pymssql
conn = pymssql.connect(
    server='localhost'
    , user='sa'
    , password='1qaz@WSX'
    , database='109PMDS'
)

# %%
import pandas as pd

sql="select 部門編號,名稱,所在縣市編號,建立時間,所屬區域,區域別 from 系統_部門表"

df = pd.read_sql(sql, conn)

# %%
pd.set_option('display.max_columns', None)

# %%
df.columns
# Out:
# Index(['部門編號', '名稱', '所在縣市編號', '建立時間', '所屬區域', '區域別'], dtype='object')

# %%
df
# Out:
#    部門編號       名稱 所在縣市編號  建立時間  所屬區域  區域別
# 0     0       全區         None  None    1
# 1    01      台北市     01  None  None   13
# 2    02      高雄市     07  None  None   14
# 3    11      基隆市     11  None  None   15
# 4    12      新竹市     12  None  None   16
# 5    17      台中市     03  None  None   17
# 6    21      台南市     05  None  None   18
# 7    22      嘉義市     22  None  None   19
# 8    31      新北市     31  None  None   20
# 9    32      桃園市     32  None  None   21
# 10   33      新竹縣     33  None  None   22
# 11   34      宜蘭縣     34  None  None   23
# 12   35      苗栗縣     35  None  None   24
# 13   36      台中縣     03  None  None   17
# 14   37      彰化縣     37  None  None   26
# 15   38      南投縣     38  None  None   27
# 16   39      雲林縣     39  None  None   28
# 17   40      嘉義縣     40  None  None   29
# 18   41      台南縣     05  None  None   18
# 19   42      高雄縣     07  None  None   14
# 20   43      屏東縣     43  None  None   32
# 21   44      澎湖縣     44  None  None   33
# ...
